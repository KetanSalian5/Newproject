# %%
import camelot
import pandas as pd
import camelot
import matplotlib.pyplot as plt

# %%
tab=camelot.read_pdf('infosys-ar-22.pdf',pages='49,50',flavor='stream')
##table_areas=['100,499,566,100'] Note table_areas accept string of the from(x1,x2,y1,y2)
#Where (x1,y1)-> top-left and (x2,y2) -> bottom-right in PDF coordinate space.the bottom-left corner of the page is origin 
#with coordinates (0, 0)

# %%
tab[0],tab[1]
# Out:
# (<Table shape=(36, 15)>, <Table shape=(42, 15)>)

# %%
tab[0].parsing_report
# Out:
# {'accuracy': 99.65, 'whitespace': 50.0, 'order': 1, 'page': 49}

# %%
tab[1].parsing_report
# Out:
# {'accuracy': 99.65, 'whitespace': 46.51, 'order': 1, 'page': 50}

# %%
tab[0].df
# Out:
#      0                    1        2            3          4        5   \
# 0   No.           subsidiary   period  acquisition  Reporting  capital
# 1                               ended                currency
# 2
# 3
# 4     1          Infosys BPM  Mar 31,           NA        INR       34
# 5                 Limited(2)     2022
# 6     2            EdgeVerve  Mar 31,           NA        INR    1,312
# 7            Systems Limited     2022
# 8     3     Infosys McCamish  Dec 31,       Dec 4,    1 USD =      175
# 9             Systems LLC(3)     2021         2009    ₹ 74.34
# 10    4      Infy Consulting  Mar 31,           NA    1 GBP =      135
# 11            Company Ltd(4)     2022                 ₹ 99.46
# 12    5       Infosys Public  Mar 31,           NA    1 USD =       98
# 13        Services, Inc. USA     2022                 ₹ 75.79
# 14    6     Stater Nederland  Dec 31,           NA    1 EUR =        8
# 15                   B.V.(5)     2021                 ₹ 84.22
# 16    7   Infosys Poland Sp.  Mar 31,       Oct 1,    1 PLN =        4
# 17                 z o.o.(3)     2022         2007    ₹ 18.21
# 18    8              Infosys  Dec 31,           NA    1 RMB =      368
# 19              Technologies     2021                  ₹ 11.7
# 20       (China) Co. Limited
# 21    9       Outbox systems  Jan 31,      Mar 13,    1 USD =      263
# 22          Inc. dba Simplus     2022         2020    ₹ 74.62
# 23                   (US)(6)
# 24   10       Infosys Compaz  Mar 31,      Nov 16,    1 SGD =       13
# 25               PTE. Ltd(7)     2022         2018    ₹ 55.97
# 26   11              Infosys  Dec 31,           NA    1 RMB =    1,004
# 27              Technologies     2021                  ₹ 11.7
# 28                (Shanghai)
# 29           Company Limited
# 30   12              Infosys  Dec 31,           NA    1 MXN =       65
# 31        Technologies S. de     2021                  ₹ 3.63
# 32            R. L. de C. V.
# 33   13   Infosys Automotive  Dec 31,           NA    1 EUR =       15
# 34              and Mobility     2021                 ₹ 84.22
# 35          GmbH & Co. KG(8)
#
#          6       7              8      9              10           11  \
# 0       and  assets     (excluding             (includes       (Loss)
# 1   surplus          share capital                inter-       before
# 2                     and reserves               company  taxation(1)
# 3                     and surplus)         transactions)
# 4     4,784   6,629          1,811  1,720          6,684        1,235
# 5
# 6     (506)   1,555            749    381          3,005        1,026
# 7
# 8       559   3,286          2,552      –          2,752          262
# 9
# 10       61     656            460      –          1,414           55
# 11
# 12      690   1,212            424      –          1,363          163
# 13
# 14      206     463            249      –          1,258          126
# 15
# 16      675   1,099            420    100            862          132
# 17
# 18     (51)     584            267      –            804           54
# 19
# 20
# 21    (207)     263            207     57            615         (31)
# 22
# 23
# 24      168     336            155      –            511           72
# 25
# 26    (327)   1,025            348      –            486         (48)
# 27
# 28
# 29
# 30      258     456            133      –            444           79
# 31
# 32
# 33     (85)   1,683          1,753      –            443         (85)
# 34
# 35
#
#              12           13            14
# 0           for       (Loss)  shareholding
# 1   taxation(1)        after
# 2                taxation(1)
# 3
# 4           275          960        100.00
# 5
# 6           276          750        100.00
# 7
# 8            72          190         99.99
# 9
# 10           24           31        100.00
# 11
# 12           46          117        100.00
# 13
# 14           31           95         75.00
# 15
# 16           24          108        100.00
# 17
# 18            –           54        100.00
# 19
# 20
# 21            –         (31)        100.00
# 22
# 23
# 24           10           62         60.00
# 25
# 26            –         (48)        100.00
# 27
# 28
# 29
# 30           20           59        100.00
# 31
# 32
# 33            –         (85)        100.00
# 34
# 35

# %%
tab[0].df
# Out:
#      0                    1        2            3          4        5   \
# 0   No.           subsidiary   period  acquisition  Reporting  capital
# 1                               ended                currency
# 2
# 3
# 4     1          Infosys BPM  Mar 31,           NA        INR       34
# 5                 Limited(2)     2022
# 6     2            EdgeVerve  Mar 31,           NA        INR    1,312
# 7            Systems Limited     2022
# 8     3     Infosys McCamish  Dec 31,       Dec 4,    1 USD =      175
# 9             Systems LLC(3)     2021         2009    ₹ 74.34
# 10    4      Infy Consulting  Mar 31,           NA    1 GBP =      135
# 11            Company Ltd(4)     2022                 ₹ 99.46
# 12    5       Infosys Public  Mar 31,           NA    1 USD =       98
# 13        Services, Inc. USA     2022                 ₹ 75.79
# 14    6     Stater Nederland  Dec 31,           NA    1 EUR =        8
# 15                   B.V.(5)     2021                 ₹ 84.22
# 16    7   Infosys Poland Sp.  Mar 31,       Oct 1,    1 PLN =        4
# 17                 z o.o.(3)     2022         2007    ₹ 18.21
# 18    8              Infosys  Dec 31,           NA    1 RMB =      368
# 19              Technologies     2021                  ₹ 11.7
# 20       (China) Co. Limited
# 21    9       Outbox systems  Jan 31,      Mar 13,    1 USD =      263
# 22          Inc. dba Simplus     2022         2020    ₹ 74.62
# 23                   (US)(6)
# 24   10       Infosys Compaz  Mar 31,      Nov 16,    1 SGD =       13
# 25               PTE. Ltd(7)     2022         2018    ₹ 55.97
# 26   11              Infosys  Dec 31,           NA    1 RMB =    1,004
# 27              Technologies     2021                  ₹ 11.7
# 28                (Shanghai)
# 29           Company Limited
# 30   12              Infosys  Dec 31,           NA    1 MXN =       65
# 31        Technologies S. de     2021                  ₹ 3.63
# 32            R. L. de C. V.
# 33   13   Infosys Automotive  Dec 31,           NA    1 EUR =       15
# 34              and Mobility     2021                 ₹ 84.22
# 35          GmbH & Co. KG(8)
#
#          6       7              8      9              10           11  \
# 0       and  assets     (excluding             (includes       (Loss)
# 1   surplus          share capital                inter-       before
# 2                     and reserves               company  taxation(1)
# 3                     and surplus)         transactions)
# 4     4,784   6,629          1,811  1,720          6,684        1,235
# 5
# 6     (506)   1,555            749    381          3,005        1,026
# 7
# 8       559   3,286          2,552      –          2,752          262
# 9
# 10       61     656            460      –          1,414           55
# 11
# 12      690   1,212            424      –          1,363          163
# 13
# 14      206     463            249      –          1,258          126
# 15
# 16      675   1,099            420    100            862          132
# 17
# 18     (51)     584            267      –            804           54
# 19
# 20
# 21    (207)     263            207     57            615         (31)
# 22
# 23
# 24      168     336            155      –            511           72
# 25
# 26    (327)   1,025            348      –            486         (48)
# 27
# 28
# 29
# 30      258     456            133      –            444           79
# 31
# 32
# 33     (85)   1,683          1,753      –            443         (85)
# 34
# 35
#
#              12           13            14
# 0           for       (Loss)  shareholding
# 1   taxation(1)        after
# 2                taxation(1)
# 3
# 4           275          960        100.00
# 5
# 6           276          750        100.00
# 7
# 8            72          190         99.99
# 9
# 10           24           31        100.00
# 11
# 12           46          117        100.00
# 13
# 14           31           95         75.00
# 15
# 16           24          108        100.00
# 17
# 18            –           54        100.00
# 19
# 20
# 21            –         (31)        100.00
# 22
# 23
# 24           10           62         60.00
# 25
# 26            –         (48)        100.00
# 27
# 28
# 29
# 30           20           59        100.00
# 31
# 32
# 33            –         (85)        100.00
# 34
# 35

# %%
tab.export('infosysnew.csv',f='csv',compress=True)

# %%
tab[0],tab[1]
# Out:
# (<Table shape=(36, 15)>, <Table shape=(42, 15)>)

# %%
camelot.plot(tab[1],kind='contour').show()
# Out:
# C:\Users\Ketan\AppData\Local\Temp\ipykernel_6776\3780137616.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tab[1],kind='contour').show()

# %%
tab=camelot.read_pdf('infosys-ar-22.pdf',pages='49',flavor='stream',)#,columns=['72,95,209,327,442,529,566,606,683'], split_text=True

# %%
tab[0].df
# Out:
#      0                    1        2            3          4        5   \
# 0   No.           subsidiary   period  acquisition  Reporting  capital
# 1                               ended                currency
# 2
# 3
# 4     1          Infosys BPM  Mar 31,           NA        INR       34
# 5                 Limited(2)     2022
# 6     2            EdgeVerve  Mar 31,           NA        INR    1,312
# 7            Systems Limited     2022
# 8     3     Infosys McCamish  Dec 31,       Dec 4,    1 USD =      175
# 9             Systems LLC(3)     2021         2009    ₹ 74.34
# 10    4      Infy Consulting  Mar 31,           NA    1 GBP =      135
# 11            Company Ltd(4)     2022                 ₹ 99.46
# 12    5       Infosys Public  Mar 31,           NA    1 USD =       98
# 13        Services, Inc. USA     2022                 ₹ 75.79
# 14    6     Stater Nederland  Dec 31,           NA    1 EUR =        8
# 15                   B.V.(5)     2021                 ₹ 84.22
# 16    7   Infosys Poland Sp.  Mar 31,       Oct 1,    1 PLN =        4
# 17                 z o.o.(3)     2022         2007    ₹ 18.21
# 18    8              Infosys  Dec 31,           NA    1 RMB =      368
# 19              Technologies     2021                  ₹ 11.7
# 20       (China) Co. Limited
# 21    9       Outbox systems  Jan 31,      Mar 13,    1 USD =      263
# 22          Inc. dba Simplus     2022         2020    ₹ 74.62
# 23                   (US)(6)
# 24   10       Infosys Compaz  Mar 31,      Nov 16,    1 SGD =       13
# 25               PTE. Ltd(7)     2022         2018    ₹ 55.97
# 26   11              Infosys  Dec 31,           NA    1 RMB =    1,004
# 27              Technologies     2021                  ₹ 11.7
# 28                (Shanghai)
# 29           Company Limited
# 30   12              Infosys  Dec 31,           NA    1 MXN =       65
# 31        Technologies S. de     2021                  ₹ 3.63
# 32            R. L. de C. V.
# 33   13   Infosys Automotive  Dec 31,           NA    1 EUR =       15
# 34              and Mobility     2021                 ₹ 84.22
# 35          GmbH & Co. KG(8)
#
#          6       7              8      9              10           11  \
# 0       and  assets     (excluding             (includes       (Loss)
# 1   surplus          share capital                inter-       before
# 2                     and reserves               company  taxation(1)
# 3                     and surplus)         transactions)
# 4     4,784   6,629          1,811  1,720          6,684        1,235
# 5
# 6     (506)   1,555            749    381          3,005        1,026
# 7
# 8       559   3,286          2,552      –          2,752          262
# 9
# 10       61     656            460      –          1,414           55
# 11
# 12      690   1,212            424      –          1,363          163
# 13
# 14      206     463            249      –          1,258          126
# 15
# 16      675   1,099            420    100            862          132
# 17
# 18     (51)     584            267      –            804           54
# 19
# 20
# 21    (207)     263            207     57            615         (31)
# 22
# 23
# 24      168     336            155      –            511           72
# 25
# 26    (327)   1,025            348      –            486         (48)
# 27
# 28
# 29
# 30      258     456            133      –            444           79
# 31
# 32
# 33     (85)   1,683          1,753      –            443         (85)
# 34
# 35
#
#              12           13            14
# 0           for       (Loss)  shareholding
# 1   taxation(1)        after
# 2                taxation(1)
# 3
# 4           275          960        100.00
# 5
# 6           276          750        100.00
# 7
# 8            72          190         99.99
# 9
# 10           24           31        100.00
# 11
# 12           46          117        100.00
# 13
# 14           31           95         75.00
# 15
# 16           24          108        100.00
# 17
# 18            –           54        100.00
# 19
# 20
# 21            –         (31)        100.00
# 22
# 23
# 24           10           62         60.00
# 25
# 26            –         (48)        100.00
# 27
# 28
# 29
# 30           20           59        100.00
# 31
# 32
# 33            –         (85)        100.00
# 34
# 35

# %%
tab=camelot.read_pdf('infosys-ar-22.pdf',pages='49',flavor='stream',columns=['72,95,209,327,442,529,566,606,683'], split_text=True)

# %%
tab[0].df
# Out:
#       0         1                               2                           3  \
# 0   No.    subsid           iary\nperiod \nacquis  ition\nReporting \ncapital
# 1                                           ended                    currency
# 2
# 3
# 4     1    Infosy            s BPM \nMar 31, \nNA                    INR\n 34
# 5          Limite                      d(2)\n2022
# 6     2     EdgeV             erve \nMar 31, \nNA                 INR\n 1,312
# 7           Syste                ms Limited\n2022
# 8     3    Infosy    s McCamish \nDec 31, \nDec 4          , \n1 USD = \n 175
# 9           Syste           ms LLC(3)\n2021\n2009                     ₹ 74.34
# 10    4    Infy C        onsulting \nMar 31, \nNA              1 GBP = \n 135
# 11           Comp                any Ltd(4)\n2022                     ₹ 99.46
# 12    5    Infosy         s Public \nMar 31, \nNA               1 USD = \n 98
# 13         Servic              es, Inc. USA\n2022                     ₹ 75.79
# 14    6    Stater        Nederland \nDec 31, \nNA                1 EUR = \n 8
# 15        B.V.(5)                            2021                     ₹ 84.22
# 16    7    Infosy  s Poland Sp. \nMar 31, \nOct 1            , \n1 PLN = \n 4
# 17       z o.o.(3                   )\n2022\n2007                     ₹ 18.21
# 18    8    Infosy                s \nDec 31, \nNA              1 RMB = \n 368
# 19          Techn                  ologies \n2021                      ₹ 11.7
# 20         (China                   ) Co. Limited
# 21    9     Outbo     x systems \nJan 31, \nMar 1         3, \n1 USD = \n 263
# 22         Inc. d         ba Simplus \n2022\n2020                     ₹ 74.62
# 23        (US)(6)
# 24   10    Infosy      s Compaz \nMar 31, \nNov 1          6, \n1 SGD = \n 13
# 25         PTE. L              td(7) \n2022\n2018                     ₹ 55.97
# 26   11    Infosy                 Dec 31, \nNA\ns            1 RMB = \n 1,004
# 27          Techn                   2021\nologies                      ₹ 11.7
# 28          (Shan                           ghai)
# 29           Comp                     any Limited
# 30   12    Infosy                s \nDec 31, \nNA               1 MXN = \n 65
# 31          Techn            ologies S. de \n2021                      ₹ 3.63
# 32        R. L. d                         e C. V.
# 33   13    Infosy     s Automotive \nDec 31, \nNA               1 EUR = \n 15
# 34          and M                  obility \n2021                     ₹ 84.22
# 35           GmbH                     & Co. KG(8)
#
#                            4               5             6              7  \
# 0   and \nassets\n(excluding        (include      s \n(Los         s) \nf
# 1     surplus\nshare capital           inter       -\nbefo  re \ntaxation
# 2               and reserves          compan  y \ntaxation            (1)
# 3               and surplus)    transactions             )
# 4     4,784 \n6,629 \n 1,811  1,720 \n 6,684          1,23        5 \n 27
# 5
# 6       (506)\n 1,555 \n 749    381 \n 3,005          1,02        6 \n 27
# 7
# 8        559\n3,286 \n 2,552      – \n 2,752            26         2 \n 7
# 9
# 10          61 \n 656 \n 460      – \n 1,414             5         5 \n 2
# 11
# 12       690 \n 1,212 \n 424      – \n 1,363            16         3 \n 4
# 13
# 14         206 \n 463 \n 249      – \n 1,258            12         6 \n 3
# 15
# 16          675\n1,099\n 420      100 \n 862            13         2 \n 2
# 17
# 18         (51)\n 584 \n 267        – \n 804             5              4
# 19
# 20
# 21        (207)\n 263 \n 207       57 \n 615            (3             1)
# 22
# 23
# 24         168 \n 336 \n 155        – \n 511             7         2 \n 1
# 25
# 26     (327) \n 1,025 \n 348        – \n 486           (48              )
# 27
# 28
# 29
# 30         258 \n 456 \n 133        – \n 444             7         9 \n 2
# 31
# 32
# 33     (85) \n1,683 \n 1,753        – \n 443           (85              )
# 34
# 35
#
#                         8      9
# 0   or \n(Loss) \nshareho  lding
# 1              (1)\nafter
# 2             taxation(1)
# 3
# 4           5 \n 960 \n 1  00.00
# 5
# 6           6 \n 750 \n 1  00.00
# 7
# 8                2 \n 190  99.99
# 9
# 10           4 \n 31 \n 1  00.00
# 11
# 12          6 \n 117 \n 1  00.00
# 13
# 14                1 \n 95  75.00
# 15
# 16          4 \n 108 \n 1  00.00
# 17
# 18           – \n 54 \n 1  00.00
# 19
# 20
# 21          –\n (31) \n 1  00.00
# 22
# 23
# 24                0 \n 62  60.00
# 25
# 26         – \n (48) \n 1  00.00
# 27
# 28
# 29
# 30           0 \n 59 \n 1  00.00
# 31
# 32
# 33          – \n (85)\n 1  00.00
# 34
# 35

# %%
tab.export('50inf.csv',f='csv',compress=True)

# %%
tab[0].to_csv('50inf.csv')

# %%
pd.read_csv('50inf.csv')
# Out:
#      No.    subsid           iary\nperiod \nacquis ition\nReporting \ncapital  \
# 0    NaN       NaN                           ended                   currency
# 1    NaN       NaN                             NaN                        NaN
# 2    NaN       NaN                             NaN                        NaN
# 3    1.0    Infosy            s BPM \nMar 31, \nNA                   INR\n 34
# 4    NaN    Limite                      d(2)\n2022                        NaN
# 5    2.0     EdgeV             erve \nMar 31, \nNA                INR\n 1,312
# 6    NaN     Syste                ms Limited\n2022                        NaN
# 7    3.0    Infosy    s McCamish \nDec 31, \nDec 4         , \n1 USD = \n 175
# 8    NaN     Syste           ms LLC(3)\n2021\n2009                    ₹ 74.34
# 9    4.0    Infy C        onsulting \nMar 31, \nNA             1 GBP = \n 135
# 10   NaN      Comp                any Ltd(4)\n2022                    ₹ 99.46
# 11   5.0    Infosy         s Public \nMar 31, \nNA              1 USD = \n 98
# 12   NaN    Servic              es, Inc. USA\n2022                    ₹ 75.79
# 13   6.0    Stater        Nederland \nDec 31, \nNA               1 EUR = \n 8
# 14   NaN   B.V.(5)                            2021                    ₹ 84.22
# 15   7.0    Infosy  s Poland Sp. \nMar 31, \nOct 1           , \n1 PLN = \n 4
# 16   NaN  z o.o.(3                   )\n2022\n2007                    ₹ 18.21
# 17   8.0    Infosy                s \nDec 31, \nNA             1 RMB = \n 368
# 18   NaN     Techn                  ologies \n2021                     ₹ 11.7
# 19   NaN    (China                   ) Co. Limited                        NaN
# 20   9.0     Outbo     x systems \nJan 31, \nMar 1        3, \n1 USD = \n 263
# 21   NaN    Inc. d         ba Simplus \n2022\n2020                    ₹ 74.62
# 22   NaN   (US)(6)                             NaN                        NaN
# 23  10.0    Infosy      s Compaz \nMar 31, \nNov 1         6, \n1 SGD = \n 13
# 24   NaN    PTE. L              td(7) \n2022\n2018                    ₹ 55.97
# 25  11.0    Infosy                 Dec 31, \nNA\ns           1 RMB = \n 1,004
# 26   NaN     Techn                   2021\nologies                     ₹ 11.7
# 27   NaN     (Shan                           ghai)                        NaN
# 28   NaN      Comp                     any Limited                        NaN
# 29  12.0    Infosy                s \nDec 31, \nNA              1 MXN = \n 65
# 30   NaN     Techn            ologies S. de \n2021                     ₹ 3.63
# 31   NaN   R. L. d                         e C. V.                        NaN
# 32  13.0    Infosy     s Automotive \nDec 31, \nNA              1 EUR = \n 15
# 33   NaN     and M                  obility \n2021                    ₹ 84.22
# 34   NaN      GmbH                     & Co. KG(8)                        NaN
#
#    and \nassets\n(excluding        (include      s \n(Los         s) \nf  \
# 0    surplus\nshare capital           inter       -\nbefo  re \ntaxation
# 1              and reserves          compan  y \ntaxation            (1)
# 2              and surplus)    transactions             )            NaN
# 3    4,784 \n6,629 \n 1,811  1,720 \n 6,684          1,23        5 \n 27
# 4                       NaN             NaN           NaN            NaN
# 5      (506)\n 1,555 \n 749    381 \n 3,005          1,02        6 \n 27
# 6                       NaN             NaN           NaN            NaN
# 7       559\n3,286 \n 2,552      – \n 2,752            26         2 \n 7
# 8                       NaN             NaN           NaN            NaN
# 9          61 \n 656 \n 460      – \n 1,414             5         5 \n 2
# 10                      NaN             NaN           NaN            NaN
# 11      690 \n 1,212 \n 424      – \n 1,363            16         3 \n 4
# 12                      NaN             NaN           NaN            NaN
# 13        206 \n 463 \n 249      – \n 1,258            12         6 \n 3
# 14                      NaN             NaN           NaN            NaN
# 15         675\n1,099\n 420      100 \n 862            13         2 \n 2
# 16                      NaN             NaN           NaN            NaN
# 17        (51)\n 584 \n 267        – \n 804             5              4
# 18                      NaN             NaN           NaN            NaN
# 19                      NaN             NaN           NaN            NaN
# 20       (207)\n 263 \n 207       57 \n 615            (3             1)
# 21                      NaN             NaN           NaN            NaN
# 22                      NaN             NaN           NaN            NaN
# 23        168 \n 336 \n 155        – \n 511             7         2 \n 1
# 24                      NaN             NaN           NaN            NaN
# 25    (327) \n 1,025 \n 348        – \n 486           (48              )
# 26                      NaN             NaN           NaN            NaN
# 27                      NaN             NaN           NaN            NaN
# 28                      NaN             NaN           NaN            NaN
# 29        258 \n 456 \n 133        – \n 444             7         9 \n 2
# 30                      NaN             NaN           NaN            NaN
# 31                      NaN             NaN           NaN            NaN
# 32    (85) \n1,683 \n 1,753        – \n 443           (85              )
# 33                      NaN             NaN           NaN            NaN
# 34                      NaN             NaN           NaN            NaN
#
#    or \n(Loss) \nshareho  lding
# 0             (1)\nafter    NaN
# 1            taxation(1)    NaN
# 2                    NaN    NaN
# 3          5 \n 960 \n 1   0.00
# 4                    NaN    NaN
# 5          6 \n 750 \n 1   0.00
# 6                    NaN    NaN
# 7               2 \n 190  99.99
# 8                    NaN    NaN
# 9           4 \n 31 \n 1   0.00
# 10                   NaN    NaN
# 11         6 \n 117 \n 1   0.00
# 12                   NaN    NaN
# 13               1 \n 95  75.00
# 14                   NaN    NaN
# 15         4 \n 108 \n 1   0.00
# 16                   NaN    NaN
# 17          – \n 54 \n 1   0.00
# 18                   NaN    NaN
# 19                   NaN    NaN
# 20         –\n (31) \n 1   0.00
# 21                   NaN    NaN
# 22                   NaN    NaN
# 23               0 \n 62  60.00
# 24                   NaN    NaN
# 25        – \n (48) \n 1   0.00
# 26                   NaN    NaN
# 27                   NaN    NaN
# 28                   NaN    NaN
# 29          0 \n 59 \n 1   0.00
# 30                   NaN    NaN
# 31                   NaN    NaN
# 32         – \n (85)\n 1   0.00
# 33                   NaN    NaN
# 34                   NaN    NaN
